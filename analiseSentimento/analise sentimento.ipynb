# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import nltk
from nltk.metrics import ConfusionMatrix
import csv

# %%
nltk.download('rslp')
# Out:
# [nltk_data] Downloading package rslp to
# [nltk_data]     C:\Users\ti.joao\AppData\Roaming\nltk_data...
# [nltk_data]   Package rslp is already up-to-date!
# True

# %%
with open('../input/treinamento.csv', newline='') as csv_file:
    reader = csv.reader(csv_file, delimiter=';')

    base_treinamento = [tuple(row) for row in reader]

    print(base_treinamento)
# Out:
# [('estou extremamente puto agora', 'raiva'), ('estou furioso', 'raiva'), ('não aguento mais essa merda', 'raiva'), ('vai tomar no cu', 'raiva'), ('vai se fuder', 'raiva'), ('você é insuportável', 'raiva'), ('vacilão morre cedo', 'raiva'), ('eu vou te cobrir de porrada', 'raiva'), ('Estou tão feliz que não consigo parar de sorrir', 'alegria'), ('Minha alma está transbordando de alegria', 'alegria'), ('Sinto uma alegria profunda dentro de mim', 'alegria'), ('Essa notícia me encheu de alegria', 'alegria'), ('A alegria está presente em cada respiração que dou', 'alegria'), ('Estou tão feliz que poderia pular de alegria', 'alegria'), ('A alegria está me inundando por completo', 'alegria'), ('Não consigo conter a alegria que sinto agora', 'alegria'), ('Estou tão feliz que parece que meu coração vai explodir', 'alegria'), ('Esta é a alegria mais pura que já senti', 'alegria'), ('Meu coração está radiante de alegria', 'alegria'), ('Essa é uma alegria que nunca esquecerei', 'alegria'), ('A alegria está fluindo em meu sangue', 'alegria'), ('Não há nada melhor do que sentir a alegria em seu coração', 'alegria'), ('Estou tão feliz que mal consigo acreditar', 'alegria'), ('A alegria está transbordando em cada parte do meu corpo', 'alegria'), ('Esta alegria é tão intensa que me faz querer abraçar o mundo inteiro', 'alegria'), ('Sinto uma alegria tão grande que poderia chorar de felicidade', 'alegria'), ('Não há nada que possa me tirar essa alegria maravilhosa', 'alegria'), ('Estou tão feliz que sinto que posso voar', 'alegria'), ('Essa alegria é a melhor sensação que já experimentei', 'alegria'), ('A alegria está me fazendo sentir como se eu pudesse conquistar o mundo', 'alegria'), ('Essa alegria me faz sentir vivo como nunca antes', 'alegria'), ('Sinto uma alegria que preenche todo o meu ser', 'alegria'), ('Sinto uma tristeza tão grande que parece que meu coração vai parar de bater', 'tristeza'), ('Essa situação é tão triste que mal consigo suportar', 'tristeza'), ('Estou com um nó na garganta que não consigo desfazer', 'tristeza'), ('Essa notícia me encheu de alegria', 'alegria'), ('A alegria está presente em cada respiração que dou', 'alegria'), ('Estou tão feliz que poderia pular de alegria', 'alegria'), ('A alegria está me inundando por completo', 'alegria'), ('Não consigo conter a alegria que sinto agora', 'alegria'), ('Estou tão feliz que parece que meu coração vai explodir', 'alegria'), ('Esta é a alegria mais pura que já senti', 'alegria'), ('Meu coração está radiante de alegria', 'alegria'), ('Essa é uma alegria que nunca esquecerei', 'alegria'), ('A alegria está fluindo em meu sangue', 'alegria'), ('Não há nada melhor do que sentir a alegria em seu coração', 'alegria'), ('Estou tão feliz que mal consigo acreditar', 'alegria'), ('A alegria está transbordando em cada parte do meu corpo', 'alegria'), ('Esta alegria é tão intensa que me faz querer abraçar o mundo inteiro', 'alegria'), ('Sinto uma alegria tão grande que poderia chorar de felicidade', 'alegria'), ('Não há nada que possa me tirar essa alegria maravilhosa', 'alegria'), ('Estou tão feliz que sinto que posso voar', 'alegria'), ('Essa alegria é a melhor sensação que já experimentei', 'alegria'), ('A alegria está me fazendo sentir como se eu pudesse conquistar o mundo', 'alegria'), ('Essa alegria me faz sentir vivo como nunca antes', 'alegria'), ('Sinto uma alegria que preenche todo o meu ser', 'alegria'), ('A alegria me deixa sem palavras', 'alegria'), ('Não há nada mais gratificante do que sentir essa alegria pura', 'alegria'), ('A alegria me faz querer dançar até o amanhecer', 'alegria'), ('Estou tão feliz que sinto que posso viver para sempre', 'alegria'), ('Sinto uma que me faz querer gritar de felicidade', 'alegria'), ('Essa é como um raio de sol em um dia de chuva', 'alegria'), ('A me faz sentir como se eu pudesse superar qualquer obstáculo', 'alegria'), ('Estou tão feliz que sinto que posso abraçar o mundo inteiro', 'alegria'), ('Essa é tão contagiante que quero comp ...

# %%
exemplo_base = pd.DataFrame(base_treinamento)
exemplo_base.columns = ['Frase', 'Sentimento']

# print(len(base_treinamento))

print('Tamanho da base de Treinamento {}'.format(exemplo_base.shape[0]))
print(exemplo_base.Sentimento.value_counts())

print((exemplo_base.Sentimento.value_counts() / exemplo_base.shape[0]) * 100)

print(exemplo_base.sample(n=len(base_treinamento)))
# Out:
# Tamanho da base de Treinamento 1856
# neutro      491
# alegria     467
# raiva       451
# tristeza    447
# Name: Sentimento, dtype: int64
# neutro      26.454741
# alegria     25.161638
# raiva       24.299569
# tristeza    24.084052
# Name: Sentimento, dtype: float64
#                                                   Frase Sentimento
# 1533   Estou com a sensação de que tudo é um grande ...   tristeza
# 457                               A vida é linda demais    alegria
# 143   Estou tão triste que não tenho vontade de come...   tristeza
# 1396                           Sinto uma grande revolta      raiva
# 519          Não tenho preferência por nenhum dos lados     neutro
# ...                                                 ...        ...
# 851                       Não poderia estar mais feliz!    alegria
# 1238                Tô na lama a vida tá difícil demais   tristeza
# 627                               Não quero me envolver     neutro
# 570                                             Bom dia     neutro
# 1039                          estou muito puto com tudo      raiva
#
# [1856 rows x 2 columns]

# %%
def removeStopWords(texto):
    frases = []

    for (palavras, sentimentos) in texto:
        semStop = [p for p in palavras.split() if p not in lista_Stop]

        frases.append((semStop, sentimentos))

    return frases

def aplica_Stemmer(texto):
    stemmer = nltk.stem.RSLPStemmer()

    frases_sem_Stemming = []

    for(palavras, sentimentos) in texto:
        com_Stemming = [str(stemmer.stem(p)) for p in palavras.split() if p not in lista_Stop]
        frases_sem_Stemming.append((com_Stemming, sentimentos))
    
    return frases_sem_Stemming

# %%
def busca_palavras(frase):
    todas_palavras = []

    for (palavras, sentimento) in frase:
        todas_palavras.extend(palavras)
    return todas_palavras

def busca_frequencia(palavras):
    palavras = nltk.FreqDist(palavras)
    return palavras

def busca_palavras_unicas(frequencia):
    freq = frequencia.keys()
    return freq

# %%
def extrator_palavras(documento):
    doc = set(documento)
    caracteristica = {}
    for palavras in palavras_unicas_treinamento:
        caracteristica['%s' % palavras] = (palavras in doc)
    return caracteristica

def extrator_palavras_teste(documento):
    doc = set(documento)
    caracteristica = {}
    for palavras in palavras_unicas_treinamento:
        caracteristica['%s' % palavras] = (palavras in doc)
    return caracteristica

def sentimento(alegria, raiva, tristeza, neutro):
    if alegria > raiva and alegria > tristeza and alegria > neutro:
        print('O sentimento que está sentido é alegria')

    elif raiva > alegria and raiva > tristeza and raiva > neutro:
        print('O sentimento que está sentido é raiva')

    elif tristeza > alegria and tristeza > raiva and tristeza > neutro:
        print('O sentimento que está sentido é tristeza')

    elif neutro > alegria and neutro > raiva and neutro > tristeza:
        print('O sentimento que está sentido é neutro')

    else:
        print('O sentimento não encontrado')

# %%
base_teste = base_treinamento #NAO FAZER ISSO DE JEITO NENHUM

# %%
exemplo_base_teste = pd.DataFrame(base_teste)
exemplo_base_teste.columns = ['Frase', 'Sentimento']

# print('Tamanho da base de Treinamento {}'.format(exemplo_base_teste.shape[0]))
# print(exemplo_base_teste.Sentimento.value_counts())

# print((exemplo_base_teste.Sentimento.value_counts() / exemplo_base_teste.shape[0]) * 100)

lista_Stop = nltk.corpus.stopwords.words('portuguese')
lista_Stop.append('Tô') #adiciona novas palavras na lista_Stop
# print(np.transpose(lista_Stop))

frases_com_Stem_treinamento = aplica_Stemmer(base_treinamento)
# print(pd.DataFrame(frases_com_Stem_treinamento, columns=['Frase', 'Sentimento']).sample(18))

frases_com_Stem_teste = aplica_Stemmer(base_teste)
# print(pd.DataFrame(frases_com_Stem_treinamento, columns=['Frase', 'Sentimento']).sample(18))

palavras_treinamento = busca_palavras(frases_com_Stem_treinamento)
palavras_teste = busca_palavras(frases_com_Stem_teste)

# print("Quantidade de palavras na base de Treinameto {}".format(pd.DataFrame(palavras_treinamento).count()))

# %%
frequencia_treinamento = busca_frequencia(palavras_treinamento)
# print(frequencia_treinamento.most_common(5))

frequencia_teste = busca_frequencia(palavras_teste)
# print(frequencia_teste.most_common(5))

palavras_unicas_treinamento = busca_palavras_unicas(frequencia_treinamento)
palavras_unicas_teste = busca_palavras_unicas(frequencia_teste)

base_completa_treinamento = nltk.classify.apply_features(extrator_palavras, frases_com_Stem_treinamento)
base_completa_teste = nltk.classify.apply_features(extrator_palavras_teste, frases_com_Stem_teste)

classificador = nltk.NaiveBayesClassifier.train(base_completa_treinamento)
print(classificador.labels())

print(classificador.show_most_informative_features(len(base_treinamento)))

print(nltk.classify.accuracy(classificador, base_completa_teste))

# cria a tabela para ver qual calssificou errado
# Out:
# ['raiva', 'alegria', 'tristeza', 'neutro']
# Most Informative Features
#                    trist = True           triste : alegri =    131.3 : 1.0
#                    alegr = True           alegri : neutro =     89.4 : 1.0
#                     raiv = True            raiva : neutro =     70.0 : 1.0
#                    felic = True           alegri : neutro =     36.1 : 1.0
#                     falt = True            raiva : neutro =     25.8 : 1.0
#                      que = True            raiva : neutro =     23.7 : 1.0
#                      nad = True           triste : raiva  =     22.5 : 1.0
#                 alegria! = True           alegri : neutro =     20.7 : 1.0
#                     sens = True           triste : raiva  =     19.2 : 1.0
#                      ess = True            raiva : neutro =     16.8 : 1.0
#                     dess = True            raiva : neutro =     16.3 : 1.0
#                    pesso = True            raiva : neutro =     15.5 : 1.0
#                     perd = True           triste : neutro =     15.0 : 1.0
#                    feliz = True           alegri : neutro =     14.4 : 1.0
#                      pod = True           alegri : neutro =     13.7 : 1.0
#                     sent = True           alegri : raiva  =     12.8 : 1.0
#                      tão = True           alegri : neutro =     12.7 : 1.0
#                      não = True           neutro : triste =     12.6 : 1.0
#                   envolv = True           neutro : alegri =     11.1 : 1.0
#                       tô = True            raiva : triste =     10.9 : 1.0
#                 maravilh = True           alegri : neutro =     10.9 : 1.0
#                      tom = True           neutro : alegri =     10.8 : 1.0
#                        é = True           alegri : raiva  =     10.6 : 1.0
#                   vontad = True            raiva : neutro =     10.5 : 1.0
#                transbord = True           alegri : raiva  =     10.0 : 1.0
#                      sac = True            raiva : neutro =      9.8 : 1.0
#                     part = True           triste : raiva  =      9.8 : 1.0
#                     odei = True            raiva : triste =      9.6 : 1.0
#                      cad = True           alegri : neutro =      9.5 : 1.0
#                      lad = True           neutro : triste =      9.4 : 1.0
#                  difícil = True           triste : neutro =      9.2 : 1.0
#                  profund = True           triste : alegri =      9.0 : 1.0
#                 injustiç = True            raiva : triste =      8.9 : 1.0
#                      viv = True           alegri : neutro =      8.8 : 1.0
#                     pens = True           triste : alegri =      8.7 : 1.0
#                      pes = True           triste : neutro =      8.4 : 1.0
#                        o = True           neutro : triste =      8.2 : 1.0
#                  sinto-m = True           triste : neutro =      7.8 : 1.0
#                  complet = True           neutro : alegri =      7.7 : 1.0
#                      ter = True           triste : raiva  =      7.7 : 1.0
#                     cert = True           neutro : raiva  =      7.7 : 1.0
#                   consig = True           triste : neutro =      7.5 : 1.0
#                     tant = True           alegri : neutro =      7.4 : 1.0
#                     peit = True           triste : raiva  =      7.1 : 1.0
#                     gost = True           neutro : triste =      7.0 : 1.0
#                  preocup = True           neutro : triste =      7.0 : 1.0
#                      vai = True           triste : neutro =      7.0 : 1.0
#                     quer = True           neutro : triste =      6.9 : 1.0
#                      mai = True           alegri : neutro =      6.7 : 1.0
#                     mund = True           alegri : neutro =      6.5 : 1.0
#                       so = True           triste : raiva  =      6.4 : 1.0
#                    energ = True           triste : neutro =      6.2 : 1.0
#                     pres = True           triste : neutro =      6.2 : 1.0
#                      olh = True            raiva : neutro =      6.2 : 1.0
#                    quebr = True            raiva : neutro =      6.2 : 1.0
#                    demal = True           triste : neutro =      6.1 : 1.0
#                      fic = True           neutro : triste =      6.0 : 1.0
#                      vou = True            raiva : alegri =      6.0 : 1.0
#                      dia = True           alegri : raiva  =      6.0 : 1.0
#                     cans = True            raiva : alegri =      5.9 : 1.0
#                      com = True            raiva : alegri =      5.9 : 1.0
#                     emoç = True           neutro : raiva  =      5.8 : 1.0
#                      tod = True            raiva : triste =      5.8 : 1.0
#                      ach = True           neutro : triste =      5.8 : 1.0
#                     chor = True           triste : raiva  =      5.7 : 1.0
#                  acredit = True            raiva : triste =      5.6 : 1.0
#                   sorris = True           alegri : triste =      5.6 : 1.0
#                       am = True           triste : neutro =      5.5 : 1.0
#                   atitud = True            raiva : neutro =      5.4 : 1.0
#                      car = True            raiva : neutro =      5.4 : 1.0
#                    abraç = True           alegri : triste =      5.4 : 1.0
#                      sol = True           alegri : triste =      5.4 : 1.0
#                      bom = True           neutro : triste =      5.3 : 1.0
#                   melhor = True           alegri : neutro =      5.3 : 1.0
#                   coraçã = True           triste : raiva  =      5.0 : 1.0
#                   moment = True           alegri : neutro =      4.8 : 1.0
#                      vib = True           alegri : neutro =      4.8 : 1.0
#                     cont = True           alegri : raiva  =      4.8 : 1.0
#                     rost = True           alegri : raiva  =      4.8 : 1.0
#                     posi = True           alegri : triste =      4.8 : 1.0
#                      vez = True           triste : neutro =      4.8 : 1.0
#                  acontec = True           neutro : alegri =      4.8 : 1.0
#                     form = True           neutro : alegri =      4.8 : 1.0
#                     chat = True            raiva : neutro =      4.7 : 1.0
#                       lá = True           neutro : raiva  =      4.6 : 1.0
#                     amig = True           alegri : neutro =      4.6 : 1.0
#                    músic = True           neutro : triste =      4.6 : 1.0
#                     nunc = True           triste : neutro =      4.5 : 1.0
#                      vid = True           alegri : neutro =      4.5 : 1.0
#                      iss = True            raiva : alegri =      4.5 : 1.0
#                     tenh = True            raiva : alegri =      4.5 : 1.0
#                     merd = True            raiva : triste =      4.4 : 1.0
#                      lut = True           triste : raiva  =      4.4 : 1.0
#                     sobr = True           neutro : triste =      4.3 : 1.0
#                     situ = True            raiva : neutro =      4.3 : 1.0
#                     pass = True           triste : neutro =      4.2 : 1.0
#                      sei = True           triste : neutro =      4.2 : 1.0
#                       eu = True            raiva : alegri =      4.2 : 1.0
#                      cab = True           alegri : raiva  =      4.2 : 1.0
#                      fim = True           triste : neutro =      4.2 : 1.0
#                      aqu = True           alegri : triste =      4.1 : 1.0
#                      mal = True            raiva : neutro =      4.1 : 1.0
#                  respeit = True            raiva : neutro =      4.1 : 1.0
#                     deix = True            raiva : neutro =      4.1 : 1.0
#                    motiv = True           neutro : alegri =      4.1 : 1.0
#                     muit = True           neutro : alegri =      4.1 : 1.0
#                     forç = True           triste : neutro =      4.0 : 1.0
#                     segu = True           triste : neutro =      4.0 : 1.0
#                     poss = True           alegri : triste =      4.0 : 1.0
#                   realiz = True           alegri : triste =      4.0 : 1.0
#                     caus = True            raiva : neutro =      4.0 : 1.0
#                      err = True            raiva : neutro =      4.0 : 1.0
#                     séri = True            raiva : neutro =      4.0 : 1.0
#                   necess = True           neutro : raiva  =      4.0 : 1.0
#                      fas = True           neutro : triste =      3.9 : 1.0
#                   sufici = True           neutro : triste =      3.9 : 1.0
#                  trabalh = True           neutro : triste =      3.9 : 1.0
#                   chapa! = True           alegri : neutro =      3.9 : 1.0
#                     mim! = True           alegri : neutro =      3.9 : 1.0
#                    grand = True           triste : raiva  =      3.8 : 1.0
#                      dar = True            raiva : alegri =      3.8 : 1.0
#                     grit = True            raiva : alegri =      3.8 : 1.0
#                      mim = True           triste : neutro =      3.8 : 1.0
#                      lid = True            raiva : neutro =      3.7 : 1.0
#                   intens = True            raiva : alegri =      3.7 : 1.0
#                      ver = True           alegri : raiva  =      3.7 : 1.0
#                      paz = True           neutro : alegri =      3.7 : 1.0
#                    dentr = True           triste : alegri =      3.6 : 1.0
#                      bol = True            raiva : alegri =      3.5 : 1.0
#                     acab = True           alegri : triste =      3.5 : 1.0
#                    brilh = True           alegri : triste =      3.5 : 1.0
#                        a = True           alegri : neutro =      3.5 : 1.0
#                     ness = True           neutro : raiva  =      3.5 : 1.0
#                      hoj = True           neutro : triste =      3.5 : 1.0
#                      nuv = True           alegri : triste =      3.4 : 1.0
#                   import = True           neutro : triste =      3.4 : 1.0
#                      fal = True            raiva : triste =      3.4 : 1.0
#                     agor = True           neutro : raiva  =      3.4 : 1.0
#                  pessoal = True           neutro : raiva  =      3.4 : 1.0
#                      ant = True           neutro : triste =      3.3 : 1.0
#                      jog = True           neutro : triste =      3.3 : 1.0
#                   precis = True           neutro : triste =      3.3 : 1.0
#                      vej = True           triste : raiva  =      3.3 : 1.0
#                    direç = True           triste : neutro =      3.3 : 1.0
#                  encontr = True           triste : neutro =      3.3 : 1.0
#                    frent = True           triste : neutro =      3.3 : 1.0
#                     fund = True           triste : neutro =      3.3 : 1.0
#                     brav = True            raiva : neutro =      3.3 : 1.0
#                    isso! = True            raiva : neutro =      3.3 : 1.0
#                      soc = True            raiva : neutro =      3.3 : 1.0
#                     volt = True            raiva : neutro =      3.3 : 1.0
#                      int = True           alegri : triste =      3.3 : 1.0
#                    notíc = True           alegri : triste =      3.3 : 1.0
#                      cim = True           alegri : neutro =      3.2 : 1.0
#                     dand = True           alegri : neutro =      3.2 : 1.0
#               experiment = True           alegri : neutro =      3.2 : 1.0
#                    redor = True           alegri : neutro =      3.2 : 1.0
#                    sempr = True           alegri : neutro =      3.2 : 1.0
#                    apert = True           triste : alegri =      3.1 : 1.0
#                  ninguém = True           triste : alegri =      3.1 : 1.0
#                    super = True           triste : alegri =      3.1 : 1.0
#                    imens = True           triste : alegri =      3.1 : 1.0
#                   alguém = True            raiva : alegri =      3.1 : 1.0
#                     apen = True            raiva : alegri =      3.1 : 1.0
#                     sint = True           triste : neutro =      3.0 : 1.0
#                      mil = True           triste : raiva  =      3.0 : 1.0
#                     temp = True           triste : raiva  =      3.0 : 1.0
#                 desesper = True            raiva : triste =      3.0 : 1.0
#                      tra = True            raiva : triste =      3.0 : 1.0
#                indescrit = True           alegri : raiva  =      2.9 : 1.0
#                      nov = True           alegri : raiva  =      2.9 : 1.0
#                      pur = True           alegri : raiva  =      2.9 : 1.0
#                   divert = True           alegri : triste =      2.9 : 1.0
#                    famíl = True           alegri : triste =      2.9 : 1.0
#                       vo = True           alegri : triste =      2.9 : 1.0
#                      meu = True           triste : neutro =      2.9 : 1.0
#                     film = True           neutro : alegri =      2.9 : 1.0
#                    seren = True           neutro : alegri =      2.9 : 1.0
#                     vist = True           neutro : alegri =      2.9 : 1.0
#                     minh = True            raiva : neutro =      2.8 : 1.0
#                      ele = True           neutro : raiva  =      2.8 : 1.0
#                      ond = True           neutro : raiva  =      2.8 : 1.0
#                  problem = True           neutro : raiva  =      2.8 : 1.0
#                      vam = True           neutro : raiva  =      2.8 : 1.0
#                      cas = True           neutro : triste =      2.7 : 1.0
#                  convers = True           neutro : triste =      2.7 : 1.0
#                     dorm = True           neutro : triste =      2.7 : 1.0
#                      lug = True           neutro : triste =      2.7 : 1.0
#                  preench = True           triste : alegri =      2.7 : 1.0
#                     fort = True            raiva : alegri =      2.7 : 1.0
#                     sang = True            raiva : alegri =      2.7 : 1.0
#                     sair = True           triste : neutro =      2.7 : 1.0
#                 consider = True            raiva : neutro =      2.6 : 1.0
#                    parec = True           triste : alegri =      2.6 : 1.0
#                      hor = True           triste : neutro =      2.6 : 1.0
#                      luz = True           triste : neutro =      2.6 : 1.0
#                  aliment = True            raiva : neutro =      2.5 : 1.0
#                      faç = True            raiva : neutro =      2.5 : 1.0
#                      fez = True            raiva : neutro =      2.5 : 1.0
#                   result = True           neutro : alegri =      2.5 : 1.0
#                      est = True           alegri : neutro =      2.5 : 1.0
#                      flu = True           alegri : neutro =      2.5 : 1.0
#                    moral = True           alegri : neutro =      2.5 : 1.0
#                     plen = True           alegri : neutro =      2.5 : 1.0
#                      sim = True           alegri : neutro =      2.5 : 1.0
#                       fl = True           triste : alegri =      2.4 : 1.0
#                       ah = True            raiva : alegri =      2.4 : 1.0
#                      lix = True            raiva : alegri =      2.4 : 1.0
#                      fer = True           triste : raiva  =      2.4 : 1.0
#                   perceb = True           triste : raiva  =      2.4 : 1.0
#                   infern = True            raiva : triste =      2.3 : 1.0
#                      boa = True           neutro : alegri =      2.3 : 1.0
#                explicar! = True           alegri : raiva  =      2.3 : 1.0
#                    assim = True           alegri : triste =      2.2 : 1.0
#                      bel = True           alegri : triste =      2.2 : 1.0
#                     cerc = True           alegri : triste =      2.2 : 1.0
#                      fiz = True           alegri : triste =      2.2 : 1.0
#                     idad = True           alegri : triste =      2.2 : 1.0
#                   mesmo! = True           alegri : triste =      2.2 : 1.0
#                    comig = True           neutro : alegri =      2.2 : 1.0
#                      cor = True           neutro : alegri =      2.2 : 1.0
#                     mant = True           neutro : alegri =      2.2 : 1.0
#                   escolh = True           neutro : triste =      2.2 : 1.0
#                       tá = True           triste : raiva  =      2.2 : 1.0
#                     calm = True           neutro : raiva  =      2.1 : 1.0
#                      ela = True           neutro : raiva  =      2.1 : 1.0
#                       ir = True           neutro : raiva  =      2.1 : 1.0
#                      ouv = True           neutro : raiva  =      2.1 : 1.0
#                      vis = True           neutro : raiva  =      2.1 : 1.0
#                      beb = True           neutro : triste =      2.1 : 1.0
#                     emoc = True           neutro : triste =      2.1 : 1.0
#                     limb = True           neutro : triste =      2.1 : 1.0
#                     pont = True           neutro : triste =      2.1 : 1.0
#                    seman = True           neutro : triste =      2.1 : 1.0
#                 liberdad = True           neutro : alegri =      2.1 : 1.0
#                    orelh = True           alegri : raiva  =      2.1 : 1.0
#                      tud = True           triste : alegri =      2.1 : 1.0
#                      amo = True           alegri : triste =      2.1 : 1.0
#                     ench = True           alegri : raiva  =      2.0 : 1.0
#                       aí = True           neutro : alegri =      2.0 : 1.0
#                      sab = True           neutro : raiva  =      2.0 : 1.0
#                     outr = True            raiva : neutro =      2.0 : 1.0
#                   qualqu = True           alegri : neutro =      1.9 : 1.0
#                      bat = True            raiva : alegri =      1.9 : 1.0
#                      tir = True            raiva : alegri =      1.9 : 1.0
#                      dan = True           triste : neutro =      1.8 : 1.0
#                  desanim = True           triste : neutro =      1.8 : 1.0
#                      deu = True           triste : neutro =      1.8 : 1.0
#                     fech = True           triste : neutro =      1.8 : 1.0
#                      man = True           triste : neutro =      1.8 : 1.0
#                  demais! = True           alegri : raiva  =      1.8 : 1.0
#                      alm = True           triste : raiva  =      1.8 : 1.0
#                  express = True           triste : raiva  =      1.8 : 1.0
#                    cabeç = True            raiva : neutro =      1.8 : 1.0
#                     chef = True            raiva : neutro =      1.8 : 1.0
#                  control = True            raiva : neutro =      1.8 : 1.0
#                     cord = True            raiva : neutro =      1.8 : 1.0
#                       qu = True            raiva : neutro =      1.8 : 1.0
#                     tent = True            raiva : neutro =      1.8 : 1.0
#                  trânsit = True            raiva : neutro =      1.8 : 1.0
#                     chei = True           alegri : raiva  =      1.8 : 1.0
#                    receb = True           neutro : alegri =      1.8 : 1.0
#                     ajud = True           alegri : neutro =      1.8 : 1.0
#                  cachorr = True           alegri : neutro =      1.8 : 1.0
#                   esquec = True           alegri : neutro =      1.8 : 1.0
#                     vibr = True           alegri : neutro =      1.8 : 1.0
#                   caminh = True           triste : alegri =      1.7 : 1.0
#                   explic = True           triste : alegri =      1.7 : 1.0
#                     send = True           triste : alegri =      1.7 : 1.0
#                      par = True           triste : neutro =      1.7 : 1.0
#                    começ = True            raiva : alegri =      1.7 : 1.0
#                   extrem = True            raiva : alegri =      1.7 : 1.0
#                      fiq = True            raiva : alegri =      1.7 : 1.0
#                  presenç = True            raiva : alegri =      1.7 : 1.0
#                      sai = True            raiva : alegri =      1.7 : 1.0
#                    toda! = True            raiva : alegri =      1.7 : 1.0
#                    espec = True           alegri : triste =      1.7 : 1.0
#                      pra = True            raiva : triste =      1.7 : 1.0
#                    trist = False          alegri : triste =      1.7 : 1.0
#                       as = True           triste : raiva  =      1.7 : 1.0
#                    capaz = True           triste : raiva  =      1.7 : 1.0
#                 cicatriz = True           triste : raiva  =      1.7 : 1.0
#                  continu = True           triste : raiva  =      1.7 : 1.0
#                   palavr = True           triste : raiva  =      1.7 : 1.0
#                   respir = True           triste : raiva  =      1.7 : 1.0
#                    segur = True           triste : raiva  =      1.7 : 1.0
#                    polít = True           neutro : raiva  =      1.7 : 1.0
#                    press = True           neutro : raiva  =      1.7 : 1.0
#                     sorr = True           alegri : triste =      1.7 : 1.0
#                     corp = True            raiva : triste =      1.7 : 1.0
#                   direit = True            raiva : triste =      1.7 : 1.0
#                   frustr = True            raiva : triste =      1.7 : 1.0
#                      hum = True            raiva : triste =      1.7 : 1.0
#                      mão = True            raiva : triste =      1.7 : 1.0
#                     viol = True            raiva : triste =      1.7 : 1.0
#                   mudanç = True           neutro : triste =      1.6 : 1.0
#                    nada! = True           neutro : triste =      1.6 : 1.0
#                 lembranç = True           alegri : raiva  =      1.6 : 1.0
#                 aproveit = True           alegri : triste =      1.6 : 1.0
#                      cal = True           alegri : triste =      1.6 : 1.0
#                     filh = True           alegri : triste =      1.6 : 1.0
#                      gat = True           alegri : triste =      1.6 : 1.0
#                    vitór = True           alegri : triste =      1.6 : 1.0
#                    capac = True           neutro : alegri =      1.6 : 1.0
#                     cheg = True           neutro : alegri =      1.6 : 1.0
#                      dev = True           neutro : alegri =      1.6 : 1.0
#                   empolg = True           neutro : alegri =      1.6 : 1.0
#                    favor = True           neutro : alegri =      1.6 : 1.0
#                    final = True           neutro : alegri =      1.6 : 1.0
#                    manhã = True           neutro : alegri =      1.6 : 1.0
#                     parc = True           neutro : alegri =      1.6 : 1.0
#                  simples = True           neutro : alegri =      1.6 : 1.0
#                  avassal = True            raiva : triste =      1.6 : 1.0
#                      faz = True           triste : neutro =      1.5 : 1.0
#                    algum = True           neutro : raiva  =      1.5 : 1.0
#                   decepç = True           neutro : raiva  =      1.5 : 1.0
#                  incomod = True           neutro : raiva  =      1.5 : 1.0
#                     niss = True           neutro : raiva  =      1.5 : 1.0
#                  complic = True            raiva : neutro =      1.5 : 1.0
#                  estress = True            raiva : neutro =      1.5 : 1.0
#                     gent = True            raiva : neutro =      1.5 : 1.0
#                   histór = True            raiva : neutro =      1.5 : 1.0
#                    aceit = True           neutro : triste =      1.5 : 1.0
#                     frac = True           neutro : triste =      1.5 : 1.0
#                      med = True           neutro : triste =      1.5 : 1.0
#                      mud = True           neutro : triste =      1.5 : 1.0
#                       to = True           neutro : triste =      1.5 : 1.0
#                    total = True           neutro : triste =      1.5 : 1.0
#                     anim = True           neutro : alegri =      1.5 : 1.0
#                      alg = True           neutro : raiva  =      1.4 : 1.0
#                     livr = True           triste : neutro =      1.4 : 1.0
#                     corr = True            raiva : neutro =      1.4 : 1.0
#                     ment = True            raiva : triste =      1.4 : 1.0
#                    alegr = False           raiva : alegri =      1.4 : 1.0
#                 insuport = True            raiva : triste =      1.4 : 1.0
#                  consegu = True           triste : alegri =      1.3 : 1.0
#                      não = False          triste : neutro =      1.3 : 1.0
#                     curt = True           neutro : alegri =      1.3 : 1.0
#                satisfeit = True           neutro : alegri =      1.3 : 1.0
#                       dá = True           triste : raiva  =      1.3 : 1.0
#                   explod = True            raiva : alegri =      1.3 : 1.0
#                    esper = True           neutro : triste =      1.3 : 1.0
#                     raiv = False          alegri : raiva  =      1.3 : 1.0
#                      lev = True           alegri : neutro =      1.2 : 1.0
#                      pud = True           alegri : raiva  =      1.2 : 1.0
#                   suport = True           triste : raiva  =      1.2 : 1.0
#                   interi = True           neutro : alegri =      1.2 : 1.0
#                      tão = False          neutro : alegri =      1.2 : 1.0
#                     cois = True            raiva : triste =      1.2 : 1.0
#                    relaç = True           neutro : triste =      1.2 : 1.0
#                     sint = False          neutro : triste =      1.2 : 1.0
#                    contr = True           neutro : triste =      1.2 : 1.0
#                     sonh = True           alegri : triste =      1.2 : 1.0
#                      ódi = False          neutro : raiva  =      1.2 : 1.0
#                    feliz = False           raiva : alegri =      1.2 : 1.0
#                      est = False          neutro : alegri =      1.1 : 1.0
#                  sinto-m = False           raiva : triste =      1.1 : 1.0
#                      que = False          neutro : raiva  =      1.1 : 1.0
#                    felic = False           raiva : alegri =      1.1 : 1.0
#                   consig = False          neutro : triste =      1.1 : 1.0
#                       tô = False          triste : raiva  =      1.1 : 1.0
#                    grand = False           raiva : triste =      1.1 : 1.0
#                     sent = False           raiva : alegri =      1.1 : 1.0
#                    parec = False          neutro : triste =      1.1 : 1.0
#                     clim = True           triste : neutro =      1.1 : 1.0
#                    futur = True           triste : neutro =      1.1 : 1.0
#                     long = True           triste : neutro =      1.1 : 1.0
#                      pen = True           triste : neutro =      1.1 : 1.0
#                  perspec = True           triste : neutro =      1.1 : 1.0
#                      val = True           triste : neutro =      1.1 : 1.0
#                     abal = True           triste : neutro =      1.1 : 1.0
#                    abert = True           triste : neutro =      1.1 : 1.0
#                      and = True           triste : neutro =      1.1 : 1.0
#                     carr = True           triste : neutro =      1.1 : 1.0
#                    celul = True           triste : neutro =      1.1 : 1.0
#                     cham = True           triste : neutro =      1.1 : 1.0
#                  cinzent = True           triste : neutro =      1.1 : 1.0
#                   costum = True           triste : neutro =      1.1 : 1.0
#                decepcion = True           triste : neutro =      1.1 : 1.0
#                    difer = True           triste : neutro =      1.1 : 1.0
#                 diferenç = True           triste : neutro =      1.1 : 1.0
#                     dist = True           triste : neutro =      1.1 : 1.0
#                    domin = True           triste : neutro =      1.1 : 1.0
#                      ent = True           triste : neutro =      1.1 : 1.0
#                equilíbri = True           triste : neutro =      1.1 : 1.0
#                    escur = True           triste : neutro =      1.1 : 1.0
#                    exist = True           triste : neutro =      1.1 : 1.0
#                     feit = True           triste : neutro =      1.1 : 1.0
#                    físic = True           triste : neutro =      1.1 : 1.0
#                    ilusã = True           triste : neutro =      1.1 : 1.0
#                    legal = True           triste : neutro =      1.1 : 1.0
#                     letr = True           triste : neutro =      1.1 : 1.0
#                   oferec = True           triste : neutro =      1.1 : 1.0
#                 relacion = True           triste : neutro =      1.1 : 1.0
#                   relógi = True           triste : neutro =      1.1 : 1.0
#                     ruim = True           triste : neutro =      1.1 : 1.0
#                 signific = True           triste : neutro =      1.1 : 1.0
#                    visit = True           triste : neutro =      1.1 : 1.0
#                      vão = True           triste : neutro =      1.1 : 1.0
#                    neutr = False          alegri : neutro =      1.1 : 1.0
#                    arrum = True            raiva : neutro =      1.1 : 1.0
#                     azul = True            raiva : neutro =      1.1 : 1.0
#                      ced = True            raiva : neutro =      1.1 : 1.0
#                    coleg = True            raiva : neutro =      1.1 : 1.0
#                   confus = True            raiva : neutro =      1.1 : 1.0
#                   conhec = True            raiva : neutro =      1.1 : 1.0
#                  desprez = True            raiva : neutro =      1.1 : 1.0
#                     diss = True            raiva : neutro =      1.1 : 1.0
#                     educ = True            raiva : neutro =      1.1 : 1.0
#                  espírit = True            raiva : neutro =      1.1 : 1.0
#                      fod = True            raiva : neutro =      1.1 : 1.0
#                     julg = True            raiva : neutro =      1.1 : 1.0
#                    pared = True            raiva : neutro =      1.1 : 1.0
#                     port = True            raiva : neutro =      1.1 : 1.0
#                 possível = True            raiva : neutro =      1.1 : 1.0
#               preconceit = True            raiva : neutro =      1.1 : 1.0
#                 prejudic = True            raiva : neutro =      1.1 : 1.0
#                      pro = True            raiva : neutro =      1.1 : 1.0
#                       pô = True            raiva : neutro =      1.1 : 1.0
#                    quent = True            raiva : neutro =      1.1 : 1.0
#                  respons = True            raiva : neutro =      1.1 : 1.0
#                  respost = True            raiva : neutro =      1.1 : 1.0
#                        a = False          neutro : alegri =      1.1 : 1.0
#                      ess = False          neutro : raiva  =      1.1 : 1.0
#                     falt = False          alegri : raiva  =      1.1 : 1.0
#                    pesso = False          neutro : raiva  =      1.1 : 1.0
#                     situ = False          alegri : raiva  =      1.1 : 1.0
#                      nad = False           raiva : triste =      1.1 : 1.0
#                   aguent = False          neutro : raiva  =      1.1 : 1.0
#                 alegria! = False           raiva : alegri =      1.1 : 1.0
#                      vid = False          neutro : alegri =      1.1 : 1.0
#                     sens = False           raiva : triste =      1.1 : 1.0
#                   coraçã = False          neutro : triste =      1.1 : 1.0
#                      put = False          neutro : raiva  =      1.1 : 1.0
#                     tant = False          neutro : alegri =      1.1 : 1.0
#                       eu = False          triste : raiva  =      1.1 : 1.0
#                      dor = False          neutro : triste =      1.1 : 1.0
#                      tom = False          alegri : neutro =      1.1 : 1.0
#                  complet = False          alegri : neutro =      1.1 : 1.0
#                      boa = False           raiva : neutro =      1.1 : 1.0
#                entusiasm = True           alegri : neutro =      1.1 : 1.0
#                      né? = True           alegri : neutro =      1.1 : 1.0
#                     otim = True           alegri : neutro =      1.1 : 1.0
#                    acord = True           alegri : neutro =      1.1 : 1.0
#                   animal = True           alegri : neutro =      1.1 : 1.0
#                      açã = True           alegri : neutro =      1.1 : 1.0
#                      bem = True           alegri : neutro =      1.1 : 1.0
#                     café = True           alegri : neutro =      1.1 : 1.0
#                   encaix = True           alegri : neutro =      1.1 : 1.0
#                    estim = True           alegri : neutro =      1.1 : 1.0
#                     mens = True           alegri : neutro =      1.1 : 1.0
#                  montanh = True           alegri : neutro =      1.1 : 1.0
#                    obrig = True           alegri : neutro =      1.1 : 1.0
#                      oss = True           alegri : neutro =      1.1 : 1.0
#                     pint = True           alegri : neutro =      1.1 : 1.0
#                     praz = True           alegri : neutro =      1.1 : 1.0
#                     real = True           alegri : neutro =      1.1 : 1.0
#                     reun = True           alegri : neutro =      1.1 : 1.0
#                    simpl = True           alegri : neutro =      1.1 : 1.0
#                     tard = True           alegri : neutro =      1.1 : 1.0
#                   termin = True           alegri : neutro =      1.1 : 1.0
#                     viaj = True           alegri : neutro =      1.1 : 1.0
#                     deix = False          neutro : raiva  =      1.1 : 1.0
#                  profund = False          neutro : triste =      1.0 : 1.0
#                     dess = False          neutro : raiva  =      1.0 : 1.0
#                     quer = False          triste : neutro =      1.0 : 1.0
#                     perd = False          neutro : triste =      1.0 : 1.0
#              felicidade! = False          neutro : alegri =      1.0 : 1.0
#                    alívi = True           triste : alegri =      1.0 : 1.0
#                      ano = True           triste : alegri =      1.0 : 1.0
#                       ar = True           triste : alegri =      1.0 : 1.0
#                      asa = True           triste : alegri =      1.0 : 1.0
#                 borbolet = True           triste : alegri =      1.0 : 1.0
#                     chuv = True           triste : alegri =      1.0 : 1.0
#                   coisa! = True           triste : alegri =      1.0 : 1.0
#                  comigo! = True           triste : alegri =      1.0 : 1.0
#                   daquel = True           triste : alegri =      1.0 : 1.0
#                     desd = True           triste : alegri =      1.0 : 1.0
#                       dm = True           triste : alegri =      1.0 : 1.0
#                    enorm = True           triste : alegri =      1.0 : 1.0
#                   estrag = True           triste : alegri =      1.0 : 1.0
#                     fim! = True           triste : alegri =      1.0 : 1.0
#                   harmon = True           triste : alegri =      1.0 : 1.0
#                      jov = True           triste : alegri =      1.0 : 1.0
#                      mar = True           triste : alegri =      1.0 : 1.0
#                  oportun = True           triste : alegri =      1.0 : 1.0
#                     pais = True           triste : alegri =      1.0 : 1.0
#                     peix = True           triste : alegri =      1.0 : 1.0
#                   pássar = True           triste : alegri =      1.0 : 1.0
#                    quant = True           triste : alegri =      1.0 : 1.0
#                     saúd = True           triste : alegri =      1.0 : 1.0
#                     traz = True           triste : alegri =      1.0 : 1.0
#                     verd = True           triste : alegri =      1.0 : 1.0
#                     únic = True           triste : alegri =      1.0 : 1.0
#                     opin = False          alegri : neutro =      1.0 : 1.0
#                    relaç = False          alegri : neutro =      1.0 : 1.0
#                      tud = False          alegri : triste =      1.0 : 1.0
#                   import = False          alegri : neutro =      1.0 : 1.0
#                     vazi = False          neutro : triste =      1.0 : 1.0
#                    irrit = False          neutro : raiva  =      1.0 : 1.0
#                      pod = False          neutro : alegri =      1.0 : 1.0
#                    quest = False          alegri : neutro =      1.0 : 1.0
#                      tod = False          triste : raiva  =      1.0 : 1.0
#                    demal = False          neutro : triste =      1.0 : 1.0
#                     chei = False          neutro : alegri =      1.0 : 1.0
#                   envolv = False           raiva : neutro =      1.0 : 1.0
#                   aceler = True            raiva : alegri =      1.0 : 1.0
#                    brinc = True            raiva : alegri =      1.0 : 1.0
#                    carac = True            raiva : alegri =      1.0 : 1.0
#                    confi = True            raiva : alegri =      1.0 : 1.0
#                   espalh = True            raiva : alegri =      1.0 : 1.0
#                     louc = True            raiva : alegri =      1.0 : 1.0
#                        é = False          triste : alegri =      1.0 : 1.0
#                     merd = False          neutro : raiva  =      1.0 : 1.0
#                   nenhum = False          alegri : neutro =      1.0 : 1.0
#                     sobr = False          alegri : neutro =      1.0 : 1.0
#                transbord = False          neutro : alegri =      1.0 : 1.0
#                 maravilh = False           raiva : alegri =      1.0 : 1.0
#                     odei = False          neutro : raiva  =      1.0 : 1.0
#                   vontad = False          alegri : raiva  =      1.0 : 1.0
#                 tranquil = False          alegri : neutro =      1.0 : 1.0
#                      lad = False           raiva : neutro =      1.0 : 1.0
#                   sorris = False          neutro : alegri =      1.0 : 1.0
#                     part = False           raiva : triste =      1.0 : 1.0
#                 injustiç = False          neutro : raiva  =      1.0 : 1.0
#                   palhaç = False          neutro : raiva  =      1.0 : 1.0
#                      sac = False          alegri : raiva  =      1.0 : 1.0
#                      bom = False           raiva : neutro =      1.0 : 1.0
#                     mund = False          neutro : alegri =      1.0 : 1.0
#                      fic = False          triste : neutro =      1.0 : 1.0
#                     grat = False          neutro : alegri =      1.0 : 1.0
#                      dia = False           raiva : alegri =      1.0 : 1.0
#                      vou = False          alegri : raiva  =      1.0 : 1.0
#                  difícil = False          alegri : triste =      1.0 : 1.0
#                   intens = False          neutro : raiva  =      1.0 : 1.0
#                   atitud = False          alegri : raiva  =      1.0 : 1.0
#                      paz = False           raiva : neutro =      1.0 : 1.0
#                      cad = False          neutro : alegri =      1.0 : 1.0
#                      nuv = False          neutro : alegri =      1.0 : 1.0
#                     radi = False          neutro : alegri =      1.0 : 1.0
#                      mim = False          neutro : triste =      1.0 : 1.0
#                   melhor = False           raiva : alegri =      1.0 : 1.0
#                      viv = False           raiva : alegri =      1.0 : 1.0
#                     nunc = False          neutro : triste =      1.0 : 1.0
#                       tá = False           raiva : triste =      1.0 : 1.0
#                     pens = False          alegri : triste =      1.0 : 1.0
#                      pes = False          alegri : triste =      1.0 : 1.0
#                      vej = False          alegri : triste =      1.0 : 1.0
#                     form = False          triste : neutro =      1.0 : 1.0
#                        o = False          triste : neutro =      1.0 : 1.0
#                     ench = False          neutro : alegri =      1.0 : 1.0
#                      vib = False           raiva : alegri =      1.0 : 1.0
#                     pass = False          neutro : triste =      1.0 : 1.0
#                      sei = False          neutro : triste =      1.0 : 1.0
#                     peit = False          neutro : triste =      1.0 : 1.0
#                      ter = False           raiva : triste =      1.0 : 1.0
#                  neutro! = False          alegri : neutro =      1.0 : 1.0
#                  preocup = False          alegri : neutro =      1.0 : 1.0
#                     gost = False           raiva : neutro =      1.0 : 1.0
#                   explod = False          neutro : raiva  =      1.0 : 1.0
#                     cert = False           raiva : neutro =      1.0 : 1.0
#                   realiz = False          neutro : alegri =      1.0 : 1.0
#                   assunt = False          alegri : neutro =      1.0 : 1.0
#                       na = False          alegri : neutro =      1.0 : 1.0
#                   prefer = False          alegri : neutro =      1.0 : 1.0
#                       so = False          neutro : triste =      1.0 : 1.0
#                      fim = False          alegri : triste =      1.0 : 1.0
#                     furi = False          neutro : raiva  =      1.0 : 1.0
#                     porr = False          neutro : raiva  =      1.0 : 1.0
#                  respeit = False          alegri : raiva  =      1.0 : 1.0
#                      faz = False          neutro : triste =      1.0 : 1.0
#                   moment = False          neutro : alegri =      1.0 : 1.0
#                   feliz! = False          neutro : alegri =      1.0 : 1.0
#                      pul = False          neutro : alegri =      1.0 : 1.0
#                     sorr = False          neutro : alegri =      1.0 : 1.0
#                      mai = False           raiva : alegri =      1.0 : 1.0
#                      ach = False          alegri : neutro =      1.0 : 1.0
#                    decis = False          alegri : neutro =      1.0 : 1.0
#                     ness = False          alegri : neutro =      1.0 : 1.0
#                      pos = False          alegri : neutro =      1.0 : 1.0
#                       aí = False           raiva : neutro =      1.0 : 1.0
#                      hoj = False           raiva : neutro =      1.0 : 1.0
#                      vai = False          neutro : triste =      1.0 : 1.0
#                  abandon = False          neutro : triste =      1.0 : 1.0
#                     chor = False          neutro : triste =      1.0 : 1.0
#                    dentr = False          neutro : triste =      1.0 : 1.0
#                 esperanç = False          neutro : triste =      1.0 : 1.0
#                     foss = False          neutro : triste =      1.0 : 1.0
#                   saudad = False          neutro : triste =      1.0 : 1.0
#                     saíd = False          neutro : triste =      1.0 : 1.0
#                     sair = False          alegri : triste =      1.0 : 1.0
#                    energ = False           raiva : triste =      1.0 : 1.0
#                     pres = False           raiva : triste =      1.0 : 1.0
#                      bol = False          neutro : raiva  =      1.0 : 1.0
#                     cans = False          neutro : raiva  =      1.0 : 1.0
#                      ful = False          neutro : raiva  =      1.0 : 1.0
#                   indign = False          neutro : raiva  =      1.0 : 1.0
#                 consider = False          alegri : raiva  =      1.0 : 1.0
#                      fal = False          alegri : raiva  =      1.0 : 1.0
#                      lid = False          alegri : raiva  =      1.0 : 1.0
#                    quebr = False          alegri : raiva  =      1.0 : 1.0
#                    abraç = False          neutro : alegri =      1.0 : 1.0
#                  demais! = False          neutro : alegri =      1.0 : 1.0
#                     incr = False          neutro : alegri =      1.0 : 1.0
#                      int = False          neutro : alegri =      1.0 : 1.0
#                      sol = False          neutro : alegri =      1.0 : 1.0
#                    notíc = False           raiva : alegri =      1.0 : 1.0
#                     poss = False          triste : alegri =      1.0 : 1.0
#                   escolh = False          alegri : neutro =      1.0 : 1.0
#                  neutral = False          alegri : neutro =      1.0 : 1.0
#                   observ = False          alegri : neutro =      1.0 : 1.0
#                     anim = False           raiva : neutro =      1.0 : 1.0
#                     emoç = False           raiva : neutro =      1.0 : 1.0
#                      mal = False          neutro : raiva  =      1.0 : 1.0
#                      olh = False          neutro : raiva  =      1.0 : 1.0
#                      bad = False          neutro : triste =      1.0 : 1.0
#                    burac = False          neutro : triste =      1.0 : 1.0
#                     depr = False          neutro : triste =      1.0 : 1.0
#                    imens = False          neutro : triste =      1.0 : 1.0
#                     lágr = False          neutro : triste =      1.0 : 1.0
#                       am = False           raiva : triste =      1.0 : 1.0
#                  encontr = False           raiva : triste =      1.0 : 1.0
#                      com = False          alegri : raiva  =      1.0 : 1.0
#                      pra = False          triste : raiva  =      1.0 : 1.0
#                   alguém = False          neutro : raiva  =      1.0 : 1.0
#                 insuport = False          neutro : raiva  =      1.0 : 1.0
#                    sacan = False          neutro : raiva  =      1.0 : 1.0
#                  acredit = False          triste : raiva  =      1.0 : 1.0
#                      amo = False          neutro : alegri =      1.0 : 1.0
#                    orelh = False          neutro : alegri =      1.0 : 1.0
#                      pur = False          neutro : alegri =      1.0 : 1.0
#                     rost = False          neutro : alegri =      1.0 : 1.0
#                     dand = False           raiva : alegri =      1.0 : 1.0
#                     posi = False           raiva : alegri =      1.0 : 1.0
#                      ver = False           raiva : alegri =      1.0 : 1.0
#                    inter = False          alegri : neutro =      1.0 : 1.0
#                      neg = False          alegri : neutro =      1.0 : 1.0
#                      sab = False          alegri : neutro =      1.0 : 1.0
#                    músic = False           raiva : neutro =      1.0 : 1.0
# ...
#                      cur = False          neutro : alegri =      1.0 : 1.0
#                     danc = False          neutro : alegri =      1.0 : 1.0
#                  dançar! = False          neutro : alegri =      1.0 : 1.0
#                     daqu = False          neutro : alegri =      1.0 : 1.0
#                    dela! = False          neutro : alegri =      1.0 : 1.0
#                   delas! = False          neutro : alegri =      1.0 : 1.0
#                  dentro! = False          neutro : alegri =      1.0 : 1.0
#               descrever! = False          neutro : alegri =      1.0 : 1.0
#               descrevê-l = False          neutro : alegri =      1.0 : 1.0
#                  desfrut = False          neutro : alegri =      1.0 : 1.0
#                 deslumbr = False          neutro : alegri =      1.0 : 1.0
#                   divers = False          neutro : alegri =      1.0 : 1.0
#                   divirt = False          neutro : alegri =      1.0 : 1.0
#                   dizer! = False          neutro : alegri =      1.0 : 1.0
#                      doc = False          neutro : alegri =      1.0 : 1.0
#                   doido! = False          neutro : alegri =      1.0 : 1.0
#              dominando?! = False          neutro : alegri =      1.0 : 1.0
#                      don = False          neutro : alegri =      1.0 : 1.0
#                    doçur = False          neutro : alegri =      1.0 : 1.0
#                     elev = False          neutro : alegri =      1.0 : 1.0
#                  enfrent = False          neutro : alegri =      1.0 : 1.0
#                 envelhec = False          neutro : alegri =      1.0 : 1.0
#                espalhá-l = False          neutro : alegri =      1.0 : 1.0
#                espreguiç = False          neutro : alegri =      1.0 : 1.0
#                    eufor = False          neutro : alegri =      1.0 : 1.0
#                explodir! = False          neutro : alegri =      1.0 : 1.0
#                   explos = False          neutro : alegri =      1.0 : 1.0
#                   extasi = False          neutro : alegri =      1.0 : 1.0
#                  favorit = False          neutro : alegri =      1.0 : 1.0
#                 felizão! = False          neutro : alegri =      1.0 : 1.0
#                 flutuar! = False          neutro : alegri =      1.0 : 1.0
#                     font = False          neutro : alegri =      1.0 : 1.0
#                    fresc = False          neutro : alegri =      1.0 : 1.0
#                      fui = False          neutro : alegri =      1.0 : 1.0
#                    galop = False          neutro : alegri =      1.0 : 1.0
#                  gargalh = False          neutro : alegri =      1.0 : 1.0
#                 gostosa! = False          neutro : alegri =      1.0 : 1.0
#                 gratific = False          neutro : alegri =      1.0 : 1.0
#                     gême = False          neutro : alegri =      1.0 : 1.0
#                    hobby = False          neutro : alegri =      1.0 : 1.0
#                  imensa! = False          neutro : alegri =      1.0 : 1.0
#                 incompar = False          neutro : alegri =      1.0 : 1.0
#                 independ = False          neutro : alegri =      1.0 : 1.0
#           indescritível! = False          neutro : alegri =      1.0 : 1.0
#                  inesper = False          neutro : alegri =      1.0 : 1.0
#           inesquecíveis! = False          neutro : alegri =      1.0 : 1.0
#                  infinit = False          neutro : alegri =      1.0 : 1.0
#                  inigual = False          neutro : alegri =      1.0 : 1.0
#                 inteiro! = False          neutro : alegri =      1.0 : 1.0
#                     junt = False          neutro : alegri =      1.0 : 1.0
#                     larg = False          neutro : alegri =      1.0 : 1.0
#                     leal = False          neutro : alegri =      1.0 : 1.0
#                     limp = False          neutro : alegri =      1.0 : 1.0
#                   linda! = False          neutro : alegri =      1.0 : 1.0
#                      lot = False          neutro : alegri =      1.0 : 1.0
#                 maneiro! = False          neutro : alegri =      1.0 : 1.0
#                   mantém = False          neutro : alegri =      1.0 : 1.0
#                      meg = False          neutro : alegri =      1.0 : 1.0
#                   mesmo? = False          neutro : alegri =      1.0 : 1.0
#                    natur = False          neutro : alegri =      1.0 : 1.0
#                      net = False          neutro : alegri =      1.0 : 1.0
#                     noss = False          neutro : alegri =      1.0 : 1.0
#                    notic = False          neutro : alegri =      1.0 : 1.0
#                     ocas = False          neutro : alegri =      1.0 : 1.0
#                  organiz = False          neutro : alegri =      1.0 : 1.0
#                   orgulh = False          neutro : alegri =      1.0 : 1.0
#                  parabém = False          neutro : alegri =      1.0 : 1.0
#                parabéns! = False          neutro : alegri =      1.0 : 1.0
#                  parado! = False          neutro : alegri =      1.0 : 1.0
#                   parar! = False          neutro : alegri =      1.0 : 1.0
#                   paraís = False          neutro : alegri =      1.0 : 1.0
#                     parç = False          neutro : alegri =      1.0 : 1.0
#                   passei = False          neutro : alegri =      1.0 : 1.0
#                  perfeit = False          neutro : alegri =      1.0 : 1.0
#                 plenitud = False          neutro : alegri =      1.0 : 1.0
#                    poder = False          neutro : alegri =      1.0 : 1.0
#            positividade! = False          neutro : alegri =      1.0 : 1.0
#                  prazer! = False          neutro : alegri =      1.0 : 1.0
#                     preç = False          neutro : alegri =      1.0 : 1.0
#                   projet = False          neutro : alegri =      1.0 : 1.0
#                     prov = False          neutro : alegri =      1.0 : 1.0
#                     puls = False          neutro : alegri =      1.0 : 1.0
#                      pôr = False          neutro : alegri =      1.0 : 1.0
#                     quil = False          neutro : alegri =      1.0 : 1.0
#                     quis = False          neutro : alegri =      1.0 : 1.0
#                      rat = False          neutro : alegri =      1.0 : 1.0
#                reencontr = False          neutro : alegri =      1.0 : 1.0
#                  relembr = False          neutro : alegri =      1.0 : 1.0
#                   remédi = False          neutro : alegri =      1.0 : 1.0
#                    renov = False          neutro : alegri =      1.0 : 1.0
#                   replet = False          neutro : alegri =      1.0 : 1.0
#                     rind = False          neutro : alegri =      1.0 : 1.0
#                      rug = False          neutro : alegri =      1.0 : 1.0
#                    sabed = False          neutro : alegri =      1.0 : 1.0
#               satisfatór = False          neutro : alegri =      1.0 : 1.0
#              satisfação! = False          neutro : alegri =      1.0 : 1.0
#                     saud = False          neutro : alegri =      1.0 : 1.0
#                  sempre! = False          neutro : alegri =      1.0 : 1.0
#                     senh = False          neutro : alegri =      1.0 : 1.0
#             sensacional! = False          neutro : alegri =      1.0 : 1.0
#                   sinton = False          neutro : alegri =      1.0 : 1.0
#                   sobrem = False          neutro : alegri =      1.0 : 1.0
#                      sup = False          neutro : alegri =      1.0 : 1.0
#                 surreal! = False          neutro : alegri =      1.0 : 1.0
#                      só! = False          neutro : alegri =      1.0 : 1.0
#                   tanto! = False          neutro : alegri =      1.0 : 1.0
#                   tesour = False          neutro : alegri =      1.0 : 1.0
#                     text = False          neutro : alegri =      1.0 : 1.0
#                    todo! = False          neutro : alegri =      1.0 : 1.0
#                 trouxe-m = False          neutro : alegri =      1.0 : 1.0
#                       vc = False          neutro : alegri =      1.0 : 1.0
#                     vend = False          neutro : alegri =      1.0 : 1.0
#                     viag = False          neutro : alegri =      1.0 : 1.0
#                  voando! = False          neutro : alegri =      1.0 : 1.0
#                    voar! = False          neutro : alegri =      1.0 : 1.0
#                      voc = False          neutro : alegri =      1.0 : 1.0
#                    você! = False          neutro : alegri =      1.0 : 1.0
#                      xíc = False          neutro : alegri =      1.0 : 1.0
#                    êxtas = False          neutro : alegri =      1.0 : 1.0
#                     ótim = False          neutro : alegri =      1.0 : 1.0
#                   única! = False          neutro : alegri =      1.0 : 1.0
#                    acord = False           raiva : alegri =      1.0 : 1.0
#                   animal = False           raiva : alegri =      1.0 : 1.0
#                      açã = False           raiva : alegri =      1.0 : 1.0
#                     café = False           raiva : alegri =      1.0 : 1.0
#                   encaix = False           raiva : alegri =      1.0 : 1.0
#                    estim = False           raiva : alegri =      1.0 : 1.0
#                     mens = False           raiva : alegri =      1.0 : 1.0
#                  montanh = False           raiva : alegri =      1.0 : 1.0
#                    obrig = False           raiva : alegri =      1.0 : 1.0
#                      oss = False           raiva : alegri =      1.0 : 1.0
#                     pint = False           raiva : alegri =      1.0 : 1.0
#                     praz = False           raiva : alegri =      1.0 : 1.0
#                     real = False           raiva : alegri =      1.0 : 1.0
#                     reun = False           raiva : alegri =      1.0 : 1.0
#                    simpl = False           raiva : alegri =      1.0 : 1.0
#                     tard = False           raiva : alegri =      1.0 : 1.0
#                   termin = False           raiva : alegri =      1.0 : 1.0
#                     viaj = False           raiva : alegri =      1.0 : 1.0
#                  absolut = False          alegri : neutro =      1.0 : 1.0
#             acontecendo! = False          alegri : neutro =      1.0 : 1.0
#                acrescent = False          alegri : neutro =      1.0 : 1.0
#                       al = False          alegri : neutro =      1.0 : 1.0
#                    alerg = False          alegri : neutro =      1.0 : 1.0
#                     alhe = False          alegri : neutro =      1.0 : 1.0
#                   amanhã = False          alegri : neutro =      1.0 : 1.0
#                    ambos = False          alegri : neutro =      1.0 : 1.0
#                   ambígu = False          alegri : neutro =      1.0 : 1.0
#                    amor! = False          alegri : neutro =      1.0 : 1.0
#                 ansiedad = False          alegri : neutro =      1.0 : 1.0
#               ansiedade! = False          alegri : neutro =      1.0 : 1.0
#                     apag = False          alegri : neutro =      1.0 : 1.0
#                     apeg = False          alegri : neutro =      1.0 : 1.0
#                   aplaus = False          alegri : neutro =      1.0 : 1.0
#                  apreens = False          alegri : neutro =      1.0 : 1.0
#                 arrepend = False          alegri : neutro =      1.0 : 1.0
#                    arroz = False          alegri : neutro =      1.0 : 1.0
#                    atras = False          alegri : neutro =      1.0 : 1.0
#                   automá = False          alegri : neutro =      1.0 : 1.0
#                      avi = False          alegri : neutro =      1.0 : 1.0
#                      aí? = False          alegri : neutro =      1.0 : 1.0
#                     bamb = False          alegri : neutro =      1.0 : 1.0
#                     banc = False          alegri : neutro =      1.0 : 1.0
#                     banh = False          alegri : neutro =      1.0 : 1.0
#                     barb = False          alegri : neutro =      1.0 : 1.0
#                   barulh = False          alegri : neutro =      1.0 : 1.0
#                     bast = False          alegri : neutro =      1.0 : 1.0
#                  beleza? = False          alegri : neutro =      1.0 : 1.0
#                      bob = False          alegri : neutro =      1.0 : 1.0
#                     bris = False          alegri : neutro =      1.0 : 1.0
#                 brócolil = False          alegri : neutro =      1.0 : 1.0
#                 candidat = False          alegri : neutro =      1.0 : 1.0
#                   canhot = False          alegri : neutro =      1.0 : 1.0
#                  cardápi = False          alegri : neutro =      1.0 : 1.0
#                  categor = False          alegri : neutro =      1.0 : 1.0
#                   cavalh = False          alegri : neutro =      1.0 : 1.0
#                      chá = False          alegri : neutro =      1.0 : 1.0
#                     clar = False          alegri : neutro =      1.0 : 1.0
#                   coment = False          alegri : neutro =      1.0 : 1.0
#                  complex = False          alegri : neutro =      1.0 : 1.0
#                   comput = False          alegri : neutro =      1.0 : 1.0
#                   conect = False          alegri : neutro =      1.0 : 1.0
#                  conform = False          alegri : neutro =      1.0 : 1.0
#                   consci = False          alegri : neutro =      1.0 : 1.0
#                  consequ = False          alegri : neutro =      1.0 : 1.0
#                   convid = False          alegri : neutro =      1.0 : 1.0
#                   cozinh = False          alegri : neutro =      1.0 : 1.0
#                       cr = False          alegri : neutro =      1.0 : 1.0
#                  critéri = False          alegri : neutro =      1.0 : 1.0
#                    debat = False          alegri : neutro =      1.0 : 1.0
#                 decisão! = False          alegri : neutro =      1.0 : 1.0
#                    decor = False          alegri : neutro =      1.0 : 1.0
#                   defeit = False          alegri : neutro =      1.0 : 1.0
#                   defens = False          alegri : neutro =      1.0 : 1.0
#                    delic = False          alegri : neutro =      1.0 : 1.0
#                 demonstr = False          alegri : neutro =      1.0 : 1.0
#              desapegado! = False          alegri : neutro =      1.0 : 1.0
#                desconheç = False          alegri : neutro =      1.0 : 1.0
#               descontent = False          alegri : neutro =      1.0 : 1.0
#                  desculp = False          alegri : neutro =      1.0 : 1.0
#                 desenrol = False          alegri : neutro =      1.0 : 1.0
#                  desfech = False          alegri : neutro =      1.0 : 1.0
#              desiludido! = False          alegri : neutro =      1.0 : 1.0
#          desinteressado! = False          alegri : neutro =      1.0 : 1.0
#                   diagon = False          alegri : neutro =      1.0 : 1.0
#                     dinh = False          alegri : neutro =      1.0 : 1.0
#                  discurs = False          alegri : neutro =      1.0 : 1.0
#                  discuss = False          alegri : neutro =      1.0 : 1.0
#                   disput = False          alegri : neutro =      1.0 : 1.0
#                     diár = False          alegri : neutro =      1.0 : 1.0
#                      doi = False          alegri : neutro =      1.0 : 1.0
#                     dram = False          alegri : neutro =      1.0 : 1.0
#                       dê = False          alegri : neutro =      1.0 : 1.0
# None
# 0.9455818965517241

# %%
erros = []
for (frase,classe) in base_completa_teste:
    resultado = classificador.classify(frase)
    if resultado != classe:
        erros.append((classe, resultado, frase))

esperado = []
previsto = []

for (frase, classe) in base_completa_teste:
    resultado = classificador.classify(frase)
    previsto.append(resultado)
    esperado.append(classe)

matriz = ConfusionMatrix(esperado, previsto)
print(matriz)
# Out:
#          |               t |
#          |   a           r |
#          |   l   n       i |
#          |   e   e   r   s |
#          |   g   u   a   t |
#          |   r   t   i   e |
#          |   i   r   v   z |
#          |   a   o   a   a |
# ---------+-----------------+
#  alegria |<443> 13   1  10 |
#   neutro |  14<459> 10   8 |
#    raiva |   3   8<433>  7 |
# tristeza |   4  16   7<420>|
# ---------+-----------------+
# (row = reference; col = test)

# %%
#teste
teste = 'to na tranquilidade'
testeStemming = []
stemmer = nltk.stem.RSLPStemmer()

for (palavras_treinamento) in teste.split():
    comStem = [p for p in palavras_treinamento.split()]
    testeStemming.append(str(stemmer.stem(comStem[0])))

novo = extrator_palavras(testeStemming)

distribuicao = classificador.prob_classify(novo)

for classe in distribuicao.samples():
    print('%s: %f' % (classe, distribuicao.prob(classe)))
    if classe == 'alegria': 
        alegria = distribuicao.prob(classe)

    if classe == 'raiva': 
        raiva = distribuicao.prob(classe)

    if classe == 'tristeza': 
        tristeza = distribuicao.prob(classe)

    if classe == 'neutro': 
        neutro = distribuicao.prob(classe)

sentimento(alegria, raiva, tristeza, neutro)
# Out:
# raiva: 0.000188
# alegria: 0.000150
# tristeza: 0.000405
# neutro: 0.999257
# O sentimento que está sentido é neutro
